# %%
import pandas as pd
import numpy as np

df_white = pd.read_csv('winequality_white.csv', sep=';')
print('white')
display(df_white.head(2))

print('red')
df_red = pd.read_csv('winequality_red.csv', sep=';')
display(df_red.head(2))
# Out:
# white
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
# 1                 14.0                 132.0    0.994  3.3       0.49
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# red
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
# ...

# %%
# número de amostras e número de colunas em cada conjunto de dados

print(f'A amostra do vinho branco tem {df_white.shape[0]}, e {df_white.shape[1]} colunas.')

print(f'A amostra do vinho branco tem {df_red.shape[0]}, e {df_red.shape[1]} colunas.')
# Out:
# A amostra do vinho branco tem 4898, e 12 colunas.
# A amostra do vinho branco tem 1599, e 12 colunas.

# %%
# recursos com valores faltantes
df_white.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
df_red.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
# linhas duplicadas no conjunto de dados sobre vinho branco
print(f' Duplicatas tinto {df_red.duplicated().sum()}.\n Duplicatas branco {df_white.duplicated().sum()}.')
# Out:
#  Duplicatas tinto 240.
#  Duplicatas branco 937.

# %%
# número de valores únicos para qualidade em cada conjunto de dados
print(f' Valores únicos para qualidade tinto: {df_red["quality"].nunique()}.')
print(f' Valores únicos para qualidade branco: {df_white["quality"].nunique()}.')
# Out:
#  Valores únicos para qualidade tinto: 6.
#  Valores únicos para qualidade branco: 7.

# %% [markdown]
# ### Crie colunas de cor
# Crie dois vetores de tamanho igual ao número de linhas nos dataframes tinto e branco que repetem o valor “red” or “white”. O NumPy oferece uma forma bem fácil de fazer isso. Aqui está a documentação para a função repeat do NumPy. Dê uma olhada e tente você mesmo.

# %%
# crie vetor de cor para o dataframe tinto
color_red = np.repeat('red', df_red.shape[0])
print(color_red)
# crie vetor de cor para o dataframe branco
color_white = np.repeat('white', df_white.shape[0])
print(color_white)
# Out:
# ['red' 'red' 'red' ... 'red' 'red' 'red']
# ['white' 'white' 'white' ... 'white' 'white' 'white']

# %% [markdown]
# Adicione os vetores de cor aos dataframes tinto e branco. Faça isso associando uma nova coluna chamada 'color' ao vetor apropriado. A célula abaixo faz isso para o dataframe tinto.

# %%
df_red['color'] = color_red
df_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
df_white['color'] = color_white
df_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6  white
# 1      9.5        6  white
# ...

# %% [markdown]
# ### Combine dataframes com append
# Veja a documentação para a função append do Pandas e veja se você pode usar isso para descobrir como combinar os dataframes. (Bonus: Por que não estamos usando o método merge para combinar dataframes?) Se você não entender, vou te mostrar como mais tarde. Certifique-se de salvar seu trabalho neste notebook! Você irá voltar para isso mais tarde.

# %%
# anexe dataframes
df_wine = df_white.append(df_red)

# exiba o dataframe para ver se tudo deu certo
df_wine.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
print(f" Branco Original:{df_white.shape} \n Tinto Original:{df_red.shape}\n Combinado:{df_wine.shape}")
# Out:
#  Branco Original:(4898, 13)
#  Tinto Original:(1599, 13)
#  Combinado:(6497, 13)

# %% [markdown]
# ## Salve o dataset combinado
# Salve seu dataframe recém-combinado como `winequality_edited.csv`. Lembre-se de configurar `index=False` para evitar salvar com uma coluna não-nomeada!

# %%
df_wine.to_csv("winequality_edited.csv", index=False)
